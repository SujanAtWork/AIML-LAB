# %% [markdown]
# #HEART DISEASE PREDICTION AND ANALYSIS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #LOAD THE CELL

# %%
df = pd.read_csv('heart.csv')
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3   145.0   233    1        0       150     0      2.3    0
# 1   37    1   2   130.0   250    0        1       187     0      3.5    0
# 2   41    0   1   130.0   204    0        0       172     0      1.4    2
# 3   56    1   1   120.0   236    0        1       178     0      0.8    2
# 4   57    0   0   120.0   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1     1.0
# 1    0      2     1.0
# 2    0      2     1.0
# 3    0      2     1.0
# 4    0      2     1.0

# %% [markdown]
# #CHECK THE SHAPE

# %%
df.shape
# Out:
# (303, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    301 non-null    float64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    300 non-null    float64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %% [markdown]
# #STATISTICAL SUMMARY

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  301.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.534884  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.557608   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# #CHECK THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      2
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      3
# dtype: int64

# %%
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])
# Out:
# Number of rows: 303
# Number of columns: 14

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['output'].value_counts()
# Out:
# output
# 1.0    162
# 0.0    138
# Name: count, dtype: int64

# %%
df['age'].value_counts().sort_index().plot(kind='bar', figsize=(10, 5))
# Out:
# <Axes: xlabel='age'>

# %%
df['output'].value_counts(normalize=True) * 100
# Out:
# output
# 1.0    54.0
# 0.0    46.0
# Name: proportion, dtype: float64

# %%
print("cp:", df['cp'].unique())
print("sex:", df['sex'].unique())
print("fbs:", df['fbs'].unique())
print("restecg:", df['restecg'].unique())
print("exng:", df['exng'].unique())
print("slp:", df['slp'].unique())
print("caa:", df['caa'].unique())
print("thall:", df['thall'].unique())
print("output:", df['output'].unique())
# Out:
# cp: [3 2 1 0]
# sex: [1 0]
# fbs: [1 0]
# restecg: [0 1 2]
# exng: [0 1]
# slp: [0 2 1]
# caa: [0 2 1 3 4]
# thall: [1 2 3 0]
# output: [ 1. nan  0.]

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8, 5))

sns.countplot(x='output', data=df, palette='pastel')

plt.xlabel("Heart Disease")
plt.ylabel("Total Count")
plt.title("Frequency of Heart Disease")

plt.xticks([0, 1], ["No", "Yes"])

plt.show()
